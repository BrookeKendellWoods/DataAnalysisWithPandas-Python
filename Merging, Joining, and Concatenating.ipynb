# %%
import pandas as pd
import os

# %%
os.chdir("C:\\Users\\18174\\Downloads\\pandas\\pandas")
os.getcwd()
# Out:
# 'C:\\Users\\18174\\Downloads\\pandas\\pandas'

# %% [markdown]
# # Merging, Joining, and Concatenating String

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")

# %%
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")

# %%
customers=pd.read_csv("Restaurant - Customers.csv")

# %%
foods=pd.read_csv("Restaurant - Foods.csv")

# %%
week1.head(3)  #always view first 3 rows of both data frames before joining or merging
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
pd.concat(objs=[week1,week2],ignore_index=False)    #objs is short for objects, last row is
#249 because will be 2 of each index position,ignore_index=False so ignores creating new index and combines new index. #if ignore_index=True pandas will drop indexes and generate new from scratch. If you need preserve index keep ignore_index=False,and if not and want to assign each row a new place in line
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
week1.append(other=week2) #Can also call append method to concatenate data frames **does exactly the same thing**
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
sales=pd.concat([week1,week2],keys=['week1','week2'])  #there is no in place parameter so must store in variable to make permanent

# %%
sales.loc[('week1', )]  #returns only week 1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
sales.loc[("week2", )]
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [250 rows x 2 columns]

# %%
sales.loc[('week2', 4)]
# Out:
# Customer ID    267
# Food ID          3
# Name: (week2, 4), dtype: int64

# %%
sales.loc[("week2", 8)]
# Out:
# Customer ID    729
# Food ID          9
# Name: (week2, 8), dtype: int64

# %%
sales.loc[("week1", 4),"Food ID"]
# Out:
# 9

# %% [markdown]
# # inner joins

# %%
week1.merge(week2, how="inner", on= "Customer ID",suffixes=[" week 1"," week 2"])  #how parameter is how it is going to work, on specifies what columns performing join on 
# data frame the merge method being called on is left data frame and df being called on is the right df
# Out:
#     Customer ID  Food ID week 1  Food ID week 2
# 0           537               9               5
# 1           155               9               3
# 2           155               1               3
# 3           503               5               8
# 4           503               5               9
# ..          ...             ...             ...
# 57          945               5               4
# 58          343               3               5
# 59          343               3               2
# 60          343               3               7
# 61          621               9               6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"]==155]  #customer ID may be tied to one more food ID
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"]==155]  #will not dedupe values will combine in every possible combo it can
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1.merge(week2, how="inner", on=["Customer ID", "Food ID"]) #only occurances where both customer ID and food ID same across both DF
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %% [markdown]
# # Outer Joins

# %%
#use outer join to find data that is in either df or both

# %%
merged=week1.merge(week2, how="outer", on="Customer ID", suffixes=[" - Week 1", " - Week 2"],
            indicator=True) #where this is no null values that customer ID was found in both of the DF
merged.head(3)
# Out:
#    Customer ID  Food ID - Week 1  Food ID - Week 2     _merge
# 0          537               9.0               5.0       both
# 1           97               4.0               NaN  left_only
# 2          658               1.0               NaN  left_only

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask=merged["_merge"].isin(["left_only","right_only"])

# %%
merged[mask]#shows only columns present in week 1 or week 2 but not both
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# ..           ...               ...               ...         ...
# 449          855               NaN               4.0  right_only
# 450          559               NaN              10.0  right_only
# 451          276               NaN               4.0  right_only
# 452          556               NaN              10.0  right_only
# 453          252               NaN               9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# # Left Join

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1.merge(foods, how="left",on="Food ID",sort=True)#providing sort =True 
#will sort by the values in the column which it is matching
# Out:
#      Customer ID  Food ID Food Item  Price
# 0            658        1     Sushi   3.99
# 1            600        1     Sushi   3.99
# 2            155        1     Sushi   3.99
# 3            341        1     Sushi   3.99
# 4             20        1     Sushi   3.99
# ..           ...      ...       ...    ...
# 245          809       10     Drink   1.75
# 246          584       10     Drink   1.75
# 247          274       10     Drink   1.75
# 248          151       10     Drink   1.75
# 249          535       10     Drink   1.75
#
# [250 rows x 4 columns]

# %%
##left on and right on

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2=week2.merge(customers, how="left",left_on="Customer ID", right_on="ID",sort=True).drop("ID",axis="columns") #drop ID because it creates duplicate

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender      Company  \
# 0            8        6    Frances     Adams  Female     Dabshots
# 1           13        2       Ruth   Alvarez  Female  Twitterlist
# 2           21        4     Albert     Burns    Male    Rhynoodle
#
#                     Occupation
# 0                Developer III
# 1  Mechanical Systems Engineer
# 2             Junior Executive

# %%
##Merging by index with left_index and right_index values->sometimes want to merge on index values
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv", index_col="ID")
foods=pd.read_csv("Restaurant - Foods.csv", index_col="Food ID")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive

# %%
sales=week1.merge(customers,how="left",left_on="Customer ID",right_index=True,sort=True)
sales=sales.merge(foods,how="left",left_on="Food ID", right_index=True)

# %%
sales.head(3)
# Out:
#      Customer ID  Food ID First Name Last Name  Gender  Company  \
# 96             3        2      Roger     Black    Male  Tagfeed
# 143           10        2     Steven      Ryan    Male  Twinder
# 31            20        1       Lisa      Rice  Female     Oloo
#
#                         Occupation Food Item  Price
# 96               Account Executive   Burrito   9.99
# 143  Community Outreach Specialist   Burrito   9.99
# 31                   Programmer IV     Sushi   3.99

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
week1.merge(week2, how="left", left_index=True, right_index=True,suffixes=[" -  Week 1", " - Week 2"]) #to match indexes in both df
# Out:
#      Customer ID -  Week 1  Food ID -  Week 1  Customer ID - Week 2  \
# 0                      537                  9                   688
# 1                       97                  4                   813
# 2                      658                  1                   495
# 3                      202                  2                   189
# 4                      155                  9                   267
# ..                     ...                ...                   ...
# 245                    413                  9                   783
# 246                    926                  6                   556
# 247                    134                  3                   547
# 248                    396                  6                   252
# 249                    535                 10                   249
#
#      Food ID - Week 2
# 0                  10
# 1                   7
# 2                  10
# 3                   5
# 4                   3
# ...

# %% [markdown]
# # The Join() Method

# %%
satisfaction=pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head() #join usually used in cases where you have two datasets linked together but maybe come from different sources or are extracted and seperated by nature
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
satisfaction.head()
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3
# 3                    7
# 4                   10

# %%
#could do 
week1.merge(satisfaction, left_index=True, right_index=True) #but join method does it without the extra syntax
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# ..           ...      ...                  ...
# 245          413        9                    1
# 246          926        6                    2
# 247          134        3                    8
# 248          396        6                   10
# 249          535       10                    3
#
# [250 rows x 3 columns]

# %%
week1.join(satisfaction) #joins based on the index by default, can be a helpful shortcut
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# ..           ...      ...                  ...
# 245          413        9                    1
# 246          926        6                    2
# 247          134        3                    8
# 248          396        6                   10
# 249          535       10                    3
#
# [250 rows x 3 columns]

# %% [markdown]
# # Pd.merge()

# %%
week1=pd.read_csv("Restaurant - Week 1 Sales.csv")
week2=pd.read_csv("Restaurant - Week 2 Sales.csv")
customers=pd.read_csv("Restaurant - Customers.csv")
foods=pd.read_csv("Restaurant - Foods.csv")
satisfaction=pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
customers_for_week_one=pd.merge(left=week1,right=customers,left_on="Customer ID", right_on="ID")

# %%
customers_for_week_one
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0            537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1             97        4   97     Amanda   Watkins  Female        Ozu
# 2            658        1  658    Patrick      Webb    Male  Browsebug
# 3            202        2  202      Louis  Campbell    Male  Rhynoodle
# 4            155        9  155    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...  ...        ...       ...     ...        ...
# 245          413        9  413      Diane    Bailey  Female    Wikibox
# 246          926        6  926       Anne    Wagner  Female      Skyba
# 247          134        3  134      Diana      Hall  Female      Quinu
# 248          396        6  396       Juan    Romero    Male    Zoonder
# 249          535       10  535      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# ...
