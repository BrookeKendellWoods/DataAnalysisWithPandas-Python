# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\18174'

# %%
bond=pd.read_csv("jamesbond.csv", index_col='Film')
bond.sort_index(inplace=True)

# %%
bond.head(10)
# Out:
#                        Year  Years lapse      Bond actor  \
# Film
# A View to a Kill       1985          2.0     Roger Moore
# Casino Royale          2006          4.0    Daniel Craig
# Diamonds Are Forever   1971          2.0    Sean Connery
# Die Another Day        2002          3.0  Pierce Brosnan
# Dr. No                 1962          NaN    Sean Connery
# For Your Eyes Only     1981          2.0     Roger Moore
# From Russia With Love  1963          1.0    Sean Connery
# GoldenEye              1995          6.0  Pierce Brosnan
# Goldfinger             1964          1.0    Sean Connery
# Licence to Kill        1989          2.0  Timothy Dalton
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                           7                    5
# Casino Royale                              1                   11
# Diamonds Are Forever                       6                    7
# ...

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
# Out:
# Year                                         1995
# Years lapse                                     6
# Bond actor                         Pierce Brosnan
# Bond actor appearance                           1
# Villians Dispatched                            47
# Others' Dispatched                             25
# Total Dispatched                               72
# Adjusted box office                         518.5
# Actual box office                           351.9
# Adjusted budget                              76.9
# Actual budget                                  60
# Director                          Martin Campbell
# Rotten Tomatoes critic score                  82%
# Rotten Tomatoes audience score                83%
# Golden Globe nominations                        0
# Golden Globe wins                               0
# Academy Award nominations                       0
# Academy Award wins                              0
# Number of Bond drinks                           8
# ...

# %%
bond.loc["Casino Royale","Year"]
# Out:
# 2006

# %%
bond.loc["Casino Royale", ["Bond actor", "Year"]]
# Out:
# Bond actor    Daniel Craig
# Year                  2006
# Name: Casino Royale, dtype: object

# %%
bond.loc["A View to a Kill":"License to Kill","Year":"Bond actor"]
# Out:
#                        Year  Years lapse      Bond actor
# Film
# A View to a Kill       1985          2.0     Roger Moore
# Casino Royale          2006          4.0    Daniel Craig
# Diamonds Are Forever   1971          2.0    Sean Connery
# Die Another Day        2002          3.0  Pierce Brosnan
# Dr. No                 1962          NaN    Sean Connery
# For Your Eyes Only     1981          2.0     Roger Moore
# From Russia With Love  1963          1.0    Sean Connery
# GoldenEye              1995          6.0  Pierce Brosnan
# Goldfinger             1964          1.0    Sean Connery
# Licence to Kill        1989          2.0  Timothy Dalton

# %%
bond.loc["A View to a Kill", ["Year","Bond actor"]]
# Out:
# Year                 1985
# Bond actor    Roger Moore
# Name: A View to a Kill, dtype: object

# %%
bond.loc["A View to a Kill", "Year":"Bond actor"]
# Out:
# Year                  1985
# Years lapse              2
# Bond actor     Roger Moore
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[0, 0:3]
# Out:
# Year                  1985
# Years lapse              2
# Bond actor     Roger Moore
# Name: A View to a Kill, dtype: object

# %%
bond.head(5)
# Out:
#                       year Years lapse             actor  \
# Film
# A View to a Kill      1985           2         Zion King
# Casino Royale         2006           4      Daniel Craig
# Diamonds Are Forever  1971           2  Sir Sean Connery
# Die Another Day       2002           3       Reggie King
# Dr. No                1990         NaN      Brooke Woods
#
#                      Bond actor appearance Villians Dispatched  \
# Film
# A View to a Kill                         7                   5
# Casino Royale                            1                  11
# Diamonds Are Forever                     6                   7
# Die Another Day                          4                  31
# Dr. No                                   1                   4
#
#                      Others' Dispatched Total Dispatched Adjusted box office  \
# Film
# A View to a Kill                     57               62               275.2
# ...

# %%
bond.loc["Dr. No", "Bond actor"]="Sir Sean Connery"

# %%
bond.loc["Die Another Day","year":"actor"]
# Out:
# year                  2002
# Years lapse              3
# actor          Reggie King
# Name: Die Another Day, dtype: object

# %%
bond.loc["Dr. No"]
# Out:
# Year                                          1962
# Years lapse                                    NaN
# Bond actor                        Sir Sean Connery
# Bond actor appearance                            1
# Villians Dispatched                              4
# Others' Dispatched                               8
# Total Dispatched                                12
# Adjusted box office                          448.8
# Actual box office                             59.5
# Adjusted budget                                  7
# Actual budget                                  1.1
# Director                             Terence Young
# Rotten Tomatoes critic score                   96%
# Rotten Tomatoes audience score                 82%
# Golden Globe nominations                         1
# Golden Globe wins                                1
# Academy Award nominations                        0
# Academy Award wins                               0
# ...

# %%
bond.loc["Dr. No", ["Year", "Bond actor", "Director"]]=[1990, "Brooke Woods","Zion puff puff"]

# %%
bond.iloc[4]
# Out:
# Year                                        1990
# Years lapse                                  NaN
# Bond actor                          Brooke Woods
# Bond actor appearance                          1
# Villians Dispatched                            4
# Others' Dispatched                             8
# Total Dispatched                              12
# Adjusted box office                        448.8
# Actual box office                           59.5
# Adjusted budget                                7
# Actual budget                                1.1
# Director                          Zion puff puff
# Rotten Tomatoes critic score                 96%
# Rotten Tomatoes audience score               82%
# Golden Globe nominations                       1
# Golden Globe wins                              1
# Academy Award nominations                      0
# Academy Award wins                             0
# Number of Bond drinks                       11.5
# ...

# %%
Actor_is_Sean_connery=bond["Bond actor"]=="Sean Connery"

# %%
bond.loc[Actor_is_Sean_connery, "Bond actor"]="Sir Sean Connery"

# %%
actor_is_zion_king=bond["Bond actor"]=="Roger Moore"

# %%
bond.loc[actor_is_zion_king, "Bond actor"]="Zion King"
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3    Pierce Brosnan
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# GoldenEye                               1995            6    Pierce Brosnan
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2    Timothy Dalton
# Live and Let Die                        1973            2         Zion King
# ...

# %%
Reggieking=bond["Bond actor"]=="Pierce Brosnan"

# %%
bond.loc[Reggieking, "Bond actor"]="Reggie King"

# %%
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# GoldenEye                               1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2    Timothy Dalton
# Live and Let Die                        1973            2         Zion King
# ...

# %%
is_tim_dal=bond["Bond actor"]=="Timothy Dalton"

# %%
bond.loc[is_tim_dal, "Bond actor"]= "Tim Dal"

# %%
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# GoldenEye                               1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.rename(index={"GoldenEye": "Golden Eye",
                  "The World is Not Enough": "best movie ever"},inplace=True)
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.rename(mapper= {"GoldenEye": "Golden Eye",
                    "The World is Not Enough": "Best bond movie ever"}, axis=0,inplace=True)
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
adjustedbudget=bond['Adjusted budget']==158.3

# %%
bond.loc[adjustedbudget, 'Adjusted budget']=180

# %%
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
one_yr_before_max=bond['Year']==1999

# %%
bond.loc[one_yr_before_max, 'Year']=2000

# %%
bond
# Out:
#                                         Year  Years lapse        Bond actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.rename(mapper={"Bond actor": "actor", 
                   "Year": "year"}, axis=1,inplace=True)

# %%
bond.rename(mapper={"year":"years",
                   "actor":"Actor"},axis="columns",inplace=True)

# %%
bond.head(1)
# Out:
#                  years Years lapse      Actor Bond actor appearance  \
# Film
# A View to a Kill  1985           2  Zion King                     7
#
#                  Villians Dispatched Others' Dispatched Total Dispatched  \
# Film
# A View to a Kill                   5                 57               62
#
#                  Adjusted box office Actual box office Adjusted budget  ...  \
# Film                                                                    ...
# A View to a Kill               275.2             152.4            54.5  ...
#
#                  Golden Globe wins Academy Award nominations  \
# Film
# A View to a Kill                 0                         0
#
#                  Academy Award wins Number of Bond drinks Bond girls  \
# Film
# A View to a Kill                  0                  14.5          4
#
#                  Bond car make Runtime minutes Month released Rating  \
# Film
# A View to a Kill       Renault             131            May     PG
#
# ...

# %%
bond.rename(columns={"years":"year",
                    "Actor":"actor"},inplace=True)

# %%
bond.head(1)
# Out:
#                   year Years lapse      actor Bond actor appearance  \
# Film
# A View to a Kill  1985           2  Zion King                     7
#
#                  Villians Dispatched Others' Dispatched Total Dispatched  \
# Film
# A View to a Kill                   5                 57               62
#
#                  Adjusted box office Actual box office Adjusted budget  ...  \
# Film                                                                    ...
# A View to a Kill               275.2             152.4            54.5  ...
#
#                  Golden Globe wins Academy Award nominations  \
# Film
# A View to a Kill                 0                         0
#
#                  Academy Award wins Number of Bond drinks Bond girls  \
# Film
# A View to a Kill                  0                  14.5          4
#
#                  Bond car make Runtime minutes Month released Rating  \
# Film
# A View to a Kill       Renault             131            May     PG
#
# ...

# %%
bond
# Out:
#                                         year  Years lapse             actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.drop("A View to a Kill")
# Out:
#                                         year  Years lapse             actor  \
# Film
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# Moonraker                               1979            2         Zion King
# ...

# %%
bond.drop(["Thunderball","Die Another Day"])
# Out:
#                                         year  Years lapse             actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# Moonraker                               1979            2         Zion King
# ...

# %%
bond.drop("A View to a Kill")
# Out:
#                                         year  Years lapse             actor  \
# Film
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# Moonraker                               1979            2         Zion King
# ...

# %%
bond.drop(["Thunderball","Casino Royale"], axis=0)
# Out:
#                                         year  Years lapse             actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# Moonraker                               1979            2         Zion King
# ...

# %%
bond.drop("Bond actor appearance",axis=1)
# Out:
#                                         year  Years lapse             actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.drop("Years lapse",axis=1)
# Out:
#                                         year             actor  \
# Film
# A View to a Kill                        1985         Zion King
# Casino Royale                           2006      Daniel Craig
# Diamonds Are Forever                    1971  Sir Sean Connery
# Die Another Day                         2002       Reggie King
# Dr. No                                  1990      Brooke Woods
# For Your Eyes Only                      1981         Zion King
# From Russia With Love                   1963  Sir Sean Connery
# Golden Eye                              1995       Reggie King
# Goldfinger                              1964  Sir Sean Connery
# Licence to Kill                         1989           Tim Dal
# Live and Let Die                        1973         Zion King
# Moonraker                               1979         Zion King
# Octopussy                               1983         Zion King
# On Her Majesty's Secret Service         1969    George Lazenby
# ...

# %%
bond.drop(labels=["Thunderball","Pierce Brosnan"],axis=0)
# Out:
#                                  year Years lapse             actor  \
# Film
# A View to a Kill                 1985           2         Zion King
# Casino Royale                    2006           4      Daniel Craig
# Diamonds Are Forever             1971           2  Sir Sean Connery
# Die Another Day                  2002           3       Reggie King
# Dr. No                           1990         NaN      Brooke Woods
# For Your Eyes Only               1981           2         Zion King
# From Russia With Love            1963           1  Sir Sean Connery
# Golden Eye                       1995           6       Reggie King
# Goldfinger                       1964           1  Sir Sean Connery
# Licence to Kill                  1989           2           Tim Dal
# Live and Let Die                 1973           2         Zion King
# Moonraker                        1979           2         Zion King
# Octopussy                        1983           2         Zion King
# ...

# %%
bond.drop(labels=["You Only Live Twice"],axis=0,inplace=True)

# %%
bond
# Out:
#                                         year  Years lapse             actor  \
# Film
# A View to a Kill                        1985            2         Zion King
# Casino Royale                           2006            4      Daniel Craig
# Diamonds Are Forever                    1971            2  Sir Sean Connery
# Die Another Day                         2002            3       Reggie King
# Dr. No                                  1990          NaN      Brooke Woods
# For Your Eyes Only                      1981            2         Zion King
# From Russia With Love                   1963            1  Sir Sean Connery
# Golden Eye                              1995            6       Reggie King
# Goldfinger                              1964            1  Sir Sean Connery
# Licence to Kill                         1989            2           Tim Dal
# Live and Let Die                        1973            2         Zion King
# ...

# %%
bond.drop(labels=["Pierce Brosnan"],axis=0,inplace=True)

# %%
bond
# Out:
#                                  year Years lapse             actor  \
# Film
# A View to a Kill                 1985           2         Zion King
# Casino Royale                    2006           4      Daniel Craig
# Diamonds Are Forever             1971           2  Sir Sean Connery
# Die Another Day                  2002           3       Reggie King
# Dr. No                           1990         NaN      Brooke Woods
# For Your Eyes Only               1981           2         Zion King
# From Russia With Love            1963           1  Sir Sean Connery
# Golden Eye                       1995           6       Reggie King
# Goldfinger                       1964           1  Sir Sean Connery
# Licence to Kill                  1989           2           Tim Dal
# Live and Let Die                 1973           2         Zion King
# Moonraker                        1979           2         Zion King
# Octopussy                        1983           2         Zion King
# ...

# %%
bond
# Out:
#                                  year         actor Years lapse  \
# Film
# A View to a Kill                 1985  brooke woods           2
# Casino Royale                    2006  brooke woods           4
# Diamonds Are Forever             1971  brooke woods           2
# Die Another Day                  2002  brooke woods           3
# Dr. No                           1990  brooke woods         NaN
# For Your Eyes Only               1981  brooke woods           2
# From Russia With Love            1963  brooke woods           1
# Golden Eye                       1995  brooke woods           6
# Goldfinger                       1964  brooke woods           1
# Licence to Kill                  1989  brooke woods           2
# Live and Let Die                 1973  brooke woods           2
# Moonraker                        1979  brooke woods           2
# Octopussy                        1983  brooke woods           2
# On Her Majesty's Secret Service  1969  brooke woods           2
# ...

# %%
bond.rename(mapper="brooke woods":"Brooke Woods",
# Out:
#   File "<ipython-input-249-aee7f1a4c6d8>", line 1
#     bond.rename(mapper="brooke woods":"Brooke Woods")
#                                      ^
# SyntaxError: invalid syntax

# %%
bond.drop("Thunderball", axis=0)
# Out:
#                                  year         actor Years lapse  \
# Film
# A View to a Kill                 1985  brooke woods           2
# Casino Royale                    2006  brooke woods           4
# Diamonds Are Forever             1971  brooke woods           2
# Die Another Day                  2002  brooke woods           3
# Dr. No                           1990  brooke woods         NaN
# For Your Eyes Only               1981  brooke woods           2
# From Russia With Love            1963  brooke woods           1
# Golden Eye                       1995  brooke woods           6
# Goldfinger                       1964  brooke woods           1
# Licence to Kill                  1989  brooke woods           2
# Live and Let Die                 1973  brooke woods           2
# Moonraker                        1979  brooke woods           2
# Octopussy                        1983  brooke woods           2
# On Her Majesty's Secret Service  1969  brooke woods           2
# ...

# %%
bond.drop('Golden Globe wins',axis=1)
# Out:
#                                  year         actor Years lapse  \
# Film
# A View to a Kill                 1985  brooke woods           2
# Casino Royale                    2006  brooke woods           4
# Diamonds Are Forever             1971  brooke woods           2
# Die Another Day                  2002  brooke woods           3
# Dr. No                           1990  brooke woods         NaN
# For Your Eyes Only               1981  brooke woods           2
# From Russia With Love            1963  brooke woods           1
# Golden Eye                       1995  brooke woods           6
# Goldfinger                       1964  brooke woods           1
# Licence to Kill                  1989  brooke woods           2
# Live and Let Die                 1973  brooke woods           2
# Moonraker                        1979  brooke woods           2
# Octopussy                        1983  brooke woods           2
# On Her Majesty's Secret Service  1969  brooke woods           2
# ...

# %%
bond=bond['actor']=='brooke woods'

# %%
bond
# Out:
# Film
# A View to a Kill                   True
# Casino Royale                      True
# Diamonds Are Forever               True
# Die Another Day                    True
# Dr. No                             True
# For Your Eyes Only                 True
# From Russia With Love              True
# Golden Eye                         True
# Goldfinger                         True
# Licence to Kill                    True
# Live and Let Die                   True
# Moonraker                          True
# Octopussy                          True
# On Her Majesty's Secret Service    True
# Quantum of Solace                  True
# Skyfall                            True
# The Living Daylights               True
# The Man with the Golden Gun        True
# The Spy Who Loved Me               True
# best movie ever                    True
# Thunderball                        True
# Tomorrow Never Dies                True
# Name: actor, dtype: bool

# %%
bond2=bond.copy()

# %%
bond2
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond.drop(columns="Golden Globe wins")
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond=bond['Bond actor']=='Sean Connery'

# %%
bond
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia With Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World is Not Enough            False
# Thunderball                         True
# Tomorrow Never Dies                False
# You Only Live Twice                 True
# ...

# %%
bond2
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond2=bond2['Bond actor']=='Sean Connery'

# %%
bond
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia With Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World is Not Enough            False
# Thunderball                         True
# Tomorrow Never Dies                False
# You Only Live Twice                 True
# ...

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
is_sean=bond['Bond actor']=='Sean Connery'
is_sean
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia With Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World is Not Enough            False
# Thunderball                         True
# Tomorrow Never Dies                False
# You Only Live Twice                 True
# ...

# %%
bond.loc[is_sean,'Bond actor']
# Out:
# Film
# Diamonds Are Forever     Sean Connery
# Dr. No                   Sean Connery
# From Russia With Love    Sean Connery
# Goldfinger               Sean Connery
# Thunderball              Sean Connery
# You Only Live Twice      Sean Connery
# Name: Bond actor, dtype: object

# %%
bond.drop('Skyfall', axis=0)
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
sean=bond['Bond actor']=='Sean Connery'

# %%
bond.loc[sean, 'Bond actor']="Brooke Woods"

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Brooke Woods
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Brooke Woods
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Brooke Woods
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Brooke Woods
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
is_brooke=bond['Bond actor']=='Brooke Woods'

# %%
bond.loc[is_brooke, "Bond actor"]='Carl Hickens'

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Carl Hickens
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Carl Hickens
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Carl Hickens
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Carl Hickens
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Carl Hickens
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Carl Hickens
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Carl Hickens
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Carl Hickens
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
old=bond['Year']>=1940

# %%
bond.loc[old, 'Year']=2021

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 2021          2.0     Roger Moore
# Casino Royale                    2021          4.0    Daniel Craig
# Diamonds Are Forever             2021          2.0    Carl Hickens
# Die Another Day                  2021          3.0  Pierce Brosnan
# Dr. No                           2021          NaN    Carl Hickens
# For Your Eyes Only               2021          2.0     Roger Moore
# From Russia With Love            2021          1.0    Carl Hickens
# GoldenEye                        2021          6.0  Pierce Brosnan
# Goldfinger                       2021          1.0    Carl Hickens
# Licence to Kill                  2021          2.0  Timothy Dalton
# Live and Let Die                 2021          2.0     Roger Moore
# Moonraker                        2021          2.0     Roger Moore
# Octopussy                        2021          2.0     Roger Moore
# ...

# %%
del bond ['Adjusted budget']

# %%
bond.sample(n=3)
# Out:
#                   Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Moonraker         2021          2.0   Roger Moore                      4
# A View to a Kill  2021          2.0   Roger Moore                      7
# Skyfall           2021          4.0  Daniel Craig                      3
#
#                   Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Moonraker                          12                  69                81
# A View to a Kill                    5                  57                62
# Skyfall                            26                  23                49
#
#                   Adjusted box office  Actual box office  Actual budget  ...  \
# Film                                                                     ...
# Moonraker                       535.0              210.3           34.0  ...
# A View to a Kill                275.2              152.4           30.0  ...
# ...

# %%
bond.sample(frac=.24)
# Out:
#                              Year  Years lapse      Bond actor  \
# Film
# Live and Let Die             2021          2.0     Roger Moore
# The World is Not Enough      2021          2.0  Pierce Brosnan
# The Man with the Golden Gun  2021          1.0     Roger Moore
# Dr. No                       2021          NaN    Carl Hickens
# Casino Royale                2021          4.0    Daniel Craig
# Tomorrow Never Dies          2021          2.0  Pierce Brosnan
#
#                              Bond actor appearance  Villians Dispatched  \
# Film
# Live and Let Die                                 1                    8
# The World is Not Enough                          3                   27
# The Man with the Golden Gun                      2                    1
# Dr. No                                           1                    4
# Casino Royale                                    1                   11
# Tomorrow Never Dies                              2                   30
#
# ...

# %%
bond.sample(frac=.24 , axis="columns")
# Out:
#                                            Director  Bond car make  \
# Film
# A View to a Kill                          John Glen        Renault
# Casino Royale                       Martin Campbell   Aston Martin
# Diamonds Are Forever                   Guy Hamilton           Ford
# Die Another Day                        Lee Tamahori   Aston Martin
# Dr. No                                Terence Young        Sunbeam
# For Your Eyes Only                        John Glen          Lotus
# From Russia With Love                 Terence Young        Bentley
# GoldenEye                           Martin Campbell            BMW
# Goldfinger                             Guy Hamilton   Aston Martin
# Licence to Kill                           John Glen        Lincoln
# Live and Let Die                       Guy Hamilton      Chevrolet
# Moonraker                             Lewis Gilbert        Bentley
# Octopussy                                 John Glen  Mercedes-Benz
# ...

# %%
bond.sort_values("Adjusted box office", ascending=False)
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Skyfall                          2021          4.0    Daniel Craig
# Thunderball                      2021          1.0    Carl Hickens
# Goldfinger                       2021          1.0    Carl Hickens
# Casino Royale                    2021          4.0    Daniel Craig
# From Russia With Love            2021          1.0    Carl Hickens
# Moonraker                        2021          2.0     Roger Moore
# The Spy Who Loved Me             2021          3.0     Roger Moore
# GoldenEye                        2021          6.0  Pierce Brosnan
# Quantum of Solace                2021          2.0    Daniel Craig
# You Only Live Twice              2021          2.0    Carl Hickens
# Die Another Day                  2021          3.0  Pierce Brosnan
# Tomorrow Never Dies              2021          2.0  Pierce Brosnan
# Live and Let Die                 2021          2.0     Roger Moore
# ...

# %%
bond.nlargest(n=3, columns='Adjusted box office')
# Out:
#              Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# Skyfall      2021          4.0  Daniel Craig                      3
# Thunderball  2021          1.0  Carl Hickens                      4
# Goldfinger   2021          1.0  Carl Hickens                      3
#
#              Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# Skyfall                       26                  23                49
# Thunderball                   20                  90               110
# Goldfinger                     9                  68                77
#
#              Adjusted box office  Actual box office  Actual budget  ...  \
# Film                                                                ...
# Skyfall                    879.8             1108.6          200.0  ...
# Thunderball                848.1              141.2            6.8  ...
# Goldfinger                 820.4              124.9            3.0  ...
#
# ...

# %%
bond.nsmallest(n=3, columns='Adjusted box office')
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Licence to Kill                  2021          2.0  Timothy Dalton
# A View to a Kill                 2021          2.0     Roger Moore
# On Her Majesty's Secret Service  2021          2.0  George Lazenby
#
#                                  Bond actor appearance  Villians Dispatched  \
# Film
# Licence to Kill                                      2                   10
# A View to a Kill                                     7                    5
# On Her Majesty's Secret Service                      1                    5
#
#                                  Others' Dispatched  Total Dispatched  \
# Film
# Licence to Kill                                  13                23
# A View to a Kill                                 57                62
# On Her Majesty's Secret Service                  37                42
#
#                                  Adjusted box office  Actual box office  \
# Film
# ...

# %%
bond.nlargest(n=3, columns="Year")
# Out:
#                       Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# A View to a Kill      2021          2.0   Roger Moore                      7
# Casino Royale         2021          4.0  Daniel Craig                      1
# Diamonds Are Forever  2021          2.0  Carl Hickens                      6
#
#                       Villians Dispatched  Others' Dispatched  \
# Film
# A View to a Kill                        5                  57
# Casino Royale                          11                  11
# Diamonds Are Forever                    7                  42
#
#                       Total Dispatched  Adjusted box office  \
# Film
# A View to a Kill                    62                275.2
# Casino Royale                       22                581.5
# Diamonds Are Forever                49                442.5
#
#                       Actual box office  Actual budget  ... Golden Globe wins  \
# ...

# %%
bond.nlargest(n=5,columns='Year')
# Out:
#                       Year  Years lapse      Bond actor  \
# Film
# A View to a Kill      2021          2.0     Roger Moore
# Casino Royale         2021          4.0    Daniel Craig
# Diamonds Are Forever  2021          2.0    Carl Hickens
# Die Another Day       2021          3.0  Pierce Brosnan
# Dr. No                2021          NaN    Carl Hickens
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# ...

# %%
bond.nlargest(n=5, columns='Number of Bond drinks')
# Out:
#                        Year  Years lapse      Bond actor  \
# Film
# Casino Royale          2021          4.0    Daniel Craig
# Tomorrow Never Dies    2021          2.0  Pierce Brosnan
# Quantum of Solace      2021          2.0    Daniel Craig
# From Russia With Love  2021          1.0    Carl Hickens
# Skyfall                2021          4.0    Daniel Craig
#
#                        Bond actor appearance  Villians Dispatched  \
# Film
# Casino Royale                              1                   11
# Tomorrow Never Dies                        2                   30
# Quantum of Solace                          2                   16
# From Russia With Love                      2                   11
# Skyfall                                    3                   26
#
#                        Others' Dispatched  Total Dispatched  \
# Film
# Casino Royale                          11                22
# Tomorrow Never Dies                    24                54
# ...

# %%
(3.20).is_integer()
# Out:
# False

# %%
"rook" in "Brooke"
# Out:
# True

# %%
lists=[[]]*3
lists
lists[0].append('Brooke')

# %%
lists
# Out:
# [['Brooke'], ['Brooke'], ['Brooke']]

# %%
lists[0].remove("Brooke")

# %%
lists
# Out:
# [[], [], []]

# %%
lists=[[]for (i) in range(3)]

# %%
lists[0].append(3)

# %%
lists
# Out:
# [[3], [], []]

# %%
lists[1].append(3)

# %%
lists
# Out:
# [[3], [3], []]

# %%
lists[2].append(1)

# %%
lists
# Out:
# [[3], [3], [1]]

# %%
lists[0].extend(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-425-6650e4218b15> in <module>
# ----> 1 lists[0].extend(3)
#
# TypeError: 'int' object is not iterable

# %%
bond.columns=[column_name.replace(" ", "_")for column_name in bond.columns]

# %%
bond.columns
# Out:
# Index(['Year', 'Years_lapse', 'Bond_actor', 'Bond_actor_appearance',
#        'Villians_Dispatched', 'Others'_Dispatched', 'Total_Dispatched',
#        'Adjusted_box_office', 'Actual_box_office', 'Adjusted_budget',
#        'Actual_budget', 'Director', 'Rotten_Tomatoes_critic_score',
#        'Rotten_Tomatoes_audience_score', 'Golden_Globe_nominations',
#        'Golden_Globe_wins', 'Academy_Award_nominations', 'Academy_Award_wins',
#        'Number_of_Bond_drinks', 'Bond_girls', 'Bond_car_make',
#        'Runtime_minutes', 'Month_released', 'Rating', 'Bond,_James_Bond_said'],
#       dtype='object')

# %%
bond.query('Bond_actor == "Daniel Craig"')
# Out:
#                    Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# Casino Royale      2006          4.0  Daniel Craig                      1
# Quantum of Solace  2008          2.0  Daniel Craig                      2
# Skyfall            2012          4.0  Daniel Craig                      3
#
#                    Villians_Dispatched  Others'_Dispatched  Total_Dispatched  \
# Film
# Casino Royale                       11                  11                22
# Quantum of Solace                   16                  15                31
# Skyfall                             26                  23                49
#
#                    Adjusted_box_office  Actual_box_office  Adjusted_budget  \
# Film
# Casino Royale                    581.5              594.2            145.3
# Quantum of Solace                514.2              576.0            181.4
# Skyfall                          879.8             1108.6            158.1
#
# ...

# %%
bond.query('Year == "2012"')
# Out:
#          Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# Skyfall  2012          4.0  Daniel Craig                      3
#
#          Villians_Dispatched  Others'_Dispatched  Total_Dispatched  \
# Film
# Skyfall                   26                  23                49
#
#          Adjusted_box_office  Actual_box_office  Adjusted_budget  ...  \
# Film                                                              ...
# Skyfall                879.8             1108.6            158.1  ...
#
#          Golden_Globe_wins Academy_Award_nominations Academy_Award_wins  \
# Film
# Skyfall                  1                         5                  2
#
#         Number_of_Bond_drinks  Bond_girls  Bond_car_make  Runtime_minutes  \
# Film
# Skyfall                  16.0           2   Aston Martin              143
#
#          Month_released  Rating  Bond,_James_Bond_said
# Film
# Skyfall        November   PG-13                      1
#
# [1 rows x 25 columns]

# %%
bond.query('Bond_actor == "Roger Moore"')
# Out:
#                              Year  Years_lapse   Bond_actor  \
# Film
# A View to a Kill             1985          2.0  Roger Moore
# For Your Eyes Only           1981          2.0  Roger Moore
# Live and Let Die             1973          2.0  Roger Moore
# Moonraker                    1979          2.0  Roger Moore
# Octopussy                    1983          2.0  Roger Moore
# The Man with the Golden Gun  1974          1.0  Roger Moore
# The Spy Who Loved Me         1977          3.0  Roger Moore
#
#                              Bond_actor_appearance  Villians_Dispatched  \
# Film
# A View to a Kill                                 7                    5
# For Your Eyes Only                               5                   18
# Live and Let Die                                 1                    8
# Moonraker                                        4                   12
# Octopussy                                        6                   15
# ...

# %%
bond.query('Film == "A View to a Kill"')
# Out:
#                   Year  Years_lapse   Bond_actor  Bond_actor_appearance  \
# Film
# A View to a Kill  1985          2.0  Roger Moore                      7
#
#                   Villians_Dispatched  Others'_Dispatched  Total_Dispatched  \
# Film
# A View to a Kill                    5                  57                62
#
#                   Adjusted_box_office  Actual_box_office  Adjusted_budget  \
# Film
# A View to a Kill                275.2              152.4             54.5
#
#                   ...  Golden_Globe_wins Academy_Award_nominations  \
# Film              ...
# A View to a Kill  ...                  0                         0
#
#                  Academy_Award_wins Number_of_Bond_drinks  Bond_girls  \
# Film
# A View to a Kill                  0                  14.5           4
#
#                   Bond_car_make  Runtime_minutes  Month_released  Rating  \
# Film
# A View to a Kill        Renault              131             May      PG
#
# ...

# %%
bond.query("Adjusted_box_office >= 600")
# Out:
#              Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# Goldfinger   1964          1.0  Sean Connery                      3
# Skyfall      2012          4.0  Daniel Craig                      3
# Thunderball  1965          1.0  Sean Connery                      4
#
#              Villians_Dispatched  Others'_Dispatched  Total_Dispatched  \
# Film
# Goldfinger                     9                  68                77
# Skyfall                       26                  23                49
# Thunderball                   20                  90               110
#
#              Adjusted_box_office  Actual_box_office  Adjusted_budget  ...  \
# Film                                                                  ...
# Goldfinger                 820.4              124.9             18.6  ...
# Skyfall                    879.8             1108.6            158.1  ...
# Thunderball                848.1              141.2             41.9  ...
#
# ...

# %%
bond.query("Years_lapse == 1.0")
# Out:
#                              Year  Years_lapse    Bond_actor  \
# Film
# From Russia With Love        1963          1.0  Sean Connery
# Goldfinger                   1964          1.0  Sean Connery
# The Man with the Golden Gun  1974          1.0   Roger Moore
# Thunderball                  1965          1.0  Sean Connery
#
#                              Bond_actor_appearance  Villians_Dispatched  \
# Film
# From Russia With Love                            2                   11
# Goldfinger                                       3                    9
# The Man with the Golden Gun                      2                    1
# Thunderball                                      4                   20
#
#                              Others'_Dispatched  Total_Dispatched  \
# Film
# From Russia With Love                        16                27
# Goldfinger                                   68                77
# The Man with the Golden Gun                   5                 6
# ...

# %%
bond.query("Year==1963")
# Out:
#                        Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# From Russia With Love  1963          1.0  Sean Connery                      2
#
#                        Villians_Dispatched  Others'_Dispatched  \
# Film
# From Russia With Love                   11                  16
#
#                        Total_Dispatched  Adjusted_box_office  \
# Film
# From Russia With Love                27                543.8
#
#                        Actual_box_office  Adjusted_budget  ...  \
# Film                                                       ...
# From Russia With Love               78.9             12.6  ...
#
#                        Golden_Globe_wins Academy_Award_nominations  \
# Film
# From Russia With Love                  0                         0
#
#                       Academy_Award_wins Number_of_Bond_drinks  Bond_girls  \
# Film
# From Russia With Love                  0                  16.0           3
#
# ...

# %%
bond.query("Year== '1965' and Film== 'Thunderball'")
# Out:
#              Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# Thunderball  1965          1.0  Sean Connery                      4
#
#              Villians_Dispatched  Others'_Dispatched  Total_Dispatched  \
# Film
# Thunderball                   20                  90               110
#
#              Adjusted_box_office  Actual_box_office  Adjusted_budget  ...  \
# Film                                                                  ...
# Thunderball                848.1              141.2             41.9  ...
#
#              Golden_Globe_wins Academy_Award_nominations Academy_Award_wins  \
# Film
# Thunderball                  0                         1                  1
#
#             Number_of_Bond_drinks  Bond_girls  Bond_car_make  Runtime_minutes  \
# Film
# Thunderball                  14.5           5        Lincoln              130
#
#              Month_released  Rating  Bond,_James_Bond_said
# Film
# ...

# %%
bond.query("Bond_actor=='Sean Connery'")
# Out:
#                        Year  Years_lapse    Bond_actor  Bond_actor_appearance  \
# Film
# Diamonds Are Forever   1971          2.0  Sean Connery                      6
# Dr. No                 1962          NaN  Sean Connery                      1
# From Russia With Love  1963          1.0  Sean Connery                      2
# Goldfinger             1964          1.0  Sean Connery                      3
# Thunderball            1965          1.0  Sean Connery                      4
# You Only Live Twice    1967          2.0  Sean Connery                      5
#
#                        Villians_Dispatched  Others'_Dispatched  \
# Film
# Diamonds Are Forever                     7                  42
# Dr. No                                   4                   8
# From Russia With Love                   11                  16
# Goldfinger                               9                  68
# Thunderball                             20                  90
# ...

# %%
bond.query("Year>=1971 or Adjusted_box_office>=600")
# Out:
#                              Year  Years_lapse      Bond_actor  \
# Film
# A View to a Kill             1985          2.0     Roger Moore
# Casino Royale                2006          4.0    Daniel Craig
# Diamonds Are Forever         1971          2.0    Sean Connery
# Die Another Day              2002          3.0  Pierce Brosnan
# For Your Eyes Only           1981          2.0     Roger Moore
# GoldenEye                    1995          6.0  Pierce Brosnan
# Goldfinger                   1964          1.0    Sean Connery
# Licence to Kill              1989          2.0  Timothy Dalton
# Live and Let Die             1973          2.0     Roger Moore
# Moonraker                    1979          2.0     Roger Moore
# Octopussy                    1983          2.0     Roger Moore
# Quantum of Solace            2008          2.0    Daniel Craig
# Skyfall                      2012          4.0    Daniel Craig
# The Living Daylights         1987          2.0  Timothy Dalton
# ...

# %%
bond.query("Bond_actor in ['Pierce Brosnan']")
# Out:
#                          Year  Years_lapse      Bond_actor  \
# Film
# Die Another Day          2002          3.0  Pierce Brosnan
# GoldenEye                1995          6.0  Pierce Brosnan
# The World is Not Enough  1999          2.0  Pierce Brosnan
# Tomorrow Never Dies      1997          2.0  Pierce Brosnan
#
#                          Bond_actor_appearance  Villians_Dispatched  \
# Film
# Die Another Day                              4                   31
# GoldenEye                                    1                   47
# The World is Not Enough                      3                   27
# Tomorrow Never Dies                          2                   30
#
#                          Others'_Dispatched  Total_Dispatched  \
# Film
# Die Another Day                          20                51
# GoldenEye                                25                72
# The World is Not Enough                  43                70
# ...

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + " MILLION!"

# %%
convert_to_string_and_add_millions(4)
# Out:
# '4 MILLION!'

# %%
bond['Adjusted_box_office']=bond['Adjusted_box_office'].apply(convert_to_string_and_add_millions)

# %%
bond
# Out:
#                                  Year  Years_lapse      Bond_actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond.rename(mapper=["Adjusted_box_office":"Box office",
                   "Adjusted_budget":"Actual_budget"],axis=1)
# Out:
#   File "<ipython-input-500-5b8ef76bbc7a>", line 1
#     bond.rename(mapper=["Adjusted_box_office":"Box office",
#                                              ^
# SyntaxError: invalid syntax

# %%
bond.head(5)
# Out:
#                       Year  Years_lapse      Bond_actor  \
# Film
# A View to a Kill      1985          2.0     Roger Moore
# Casino Royale         2006          4.0    Daniel Craig
# Diamonds Are Forever  1971          2.0    Sean Connery
# Die Another Day       2002          3.0  Pierce Brosnan
# Dr. No                1962          NaN    Sean Connery
#
#                       Bond_actor_appearance  Villians_Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
# Dr. No                                    1                    4
#
#                       Others'_Dispatched  Total_Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# ...

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0     Roger Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0     Roger Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
is_moore=bond['Bond actor']=='Rooger Moore'

# %%
bond.loc[is_moore,'Bond actor']='Brooke Woods'

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# Dr. No                           1962          NaN    Sean Connery
# From Russia With Love            1963          1.0    Sean Connery
# Goldfinger                       1964          1.0    Sean Connery
# Thunderball                      1965          1.0    Sean Connery
# You Only Live Twice              1967          2.0    Sean Connery
# On Her Majesty's Secret Service  1969          2.0  George Lazenby
# Diamonds Are Forever             1971          2.0    Sean Connery
# Live and Let Die                 1973          2.0     Roger Moore
# The Man with the Golden Gun      1974          1.0     Roger Moore
# The Spy Who Loved Me             1977          3.0     Roger Moore
# Moonraker                        1979          2.0     Roger Moore
# For Your Eyes Only               1981          2.0     Roger Moore
# Octopussy                        1983          2.0     Roger Moore
# ...

# %%
bond=pd.read_csv("jamesbond.csv", index_col='Film')
bond.sort_index(inplace=True)

# %%
bond["Bond actor"]
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia With Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# The Living Daylights               Timothy Dalton
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# ...

# %%
is_moore=bond['Bond actor']=='Roger Moore'

# %%
bond.loc[is_moore, 'Bond actor']='Roger Moores'

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0    Roger Moores
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0    Roger Moores
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0    Roger Moores
# Moonraker                        1979          2.0    Roger Moores
# Octopussy                        1983          2.0    Roger Moores
# ...

# %%
bond.rename(mapper={"Skyfall":"Skyfalls",
                   "The Spy Who Loved Me":"This Guy Who Loved me"}, axis=0)
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0    Roger Moores
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0    Roger Moores
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0    Roger Moores
# Moonraker                        1979          2.0    Roger Moores
# Octopussy                        1983          2.0    Roger Moores
# ...

# %%
def add_millions(number):
    return str(number) + " millions"

# %%
bond['Actual budget']=bond['Actual budget'].apply(add_millions)

# %%
bond["Actual box office"]=bond["Actual box office"].apply(add_millions)

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0    Roger Moores
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0    Roger Moores
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0    Roger Moores
# Moonraker                        1979          2.0    Roger Moores
# Octopussy                        1983          2.0    Roger Moores
# ...

# %%
bond.head(4)
# Out:
#                       Year  Years lapse      Bond actor  \
# Film
# A View to a Kill      1985          2.0    Roger Moores
# Casino Royale         2006          4.0    Daniel Craig
# Diamonds Are Forever  1971          2.0    Sean Connery
# Die Another Day       2002          3.0  Pierce Brosnan
#
#                       Bond actor appearance  Villians Dispatched  \
# Film
# A View to a Kill                          7                    5
# Casino Royale                             1                   11
# Diamonds Are Forever                      6                    7
# Die Another Day                           4                   31
#
#                       Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                      57                62
# Casino Royale                         11                22
# Diamonds Are Forever                  42                49
# Die Another Day                       20                51
#
# ...

# %%
columns=["Adjusted box office", "Actual box office", "Adjusted budget"]

# %%
for col in columns:
    bond[col]=bond[col].apply(add_millions)

# %%
bond.head(2)
# Out:
#                   Year  Years lapse    Bond actor  Bond actor appearance  \
# Film
# A View to a Kill  1985          2.0   Roger Moore                      7
# Casino Royale     2006          4.0  Daniel Craig                      1
#
#                   Villians Dispatched  Others' Dispatched  Total Dispatched  \
# Film
# A View to a Kill                    5                  57                62
# Casino Royale                      11                  11                22
#
#                  Adjusted box office Actual box office Adjusted budget  ...  \
# Film                                                                    ...
# A View to a Kill      275.2 millions    152.4 millions   54.5 millions  ...
# Casino Royale         581.5 millions    594.2 millions  145.3 millions  ...
#
#                   Golden Globe wins Academy Award nominations  \
# Film
# A View to a Kill                  0                         0
# ...

# %%
def good_actor(row):
    actor=row[2]
    budget=row[9]

    if actor=="Roger Moore":
        return "The best"
    elif actor!="Roger Moore":
        return "boo"
    else:
        return "no clue"

# %%
good_actor("Daniel Craig")
# Out:
# 'boo'

# %%
bond.apply(good_actor, axis="columns")
# Out:
# Film
# A View to a Kill                   The best
# Casino Royale                           boo
# Diamonds Are Forever                    boo
# Die Another Day                         boo
# Dr. No                                  boo
# For Your Eyes Only                 The best
# From Russia With Love                   boo
# GoldenEye                               boo
# Goldfinger                              boo
# Licence to Kill                         boo
# Live and Let Die                   The best
# Moonraker                          The best
# Octopussy                          The best
# On Her Majesty's Secret Service         boo
# Quantum of Solace                       boo
# Skyfall                                 boo
# The Living Daylights                    boo
# The Man with the Golden Gun        The best
# The Spy Who Loved Me               The best
# The World is Not Enough                 boo
# Thunderball                             boo
# ...

# %%
import matplotlib.pyplot as plt

# %%
bond.dtypes
# Out:
# Year                                int64
# Years lapse                       float64
# Bond actor                         object
# Bond actor appearance               int64
# Villians Dispatched                 int64
# Others' Dispatched                  int64
# Total Dispatched                    int64
# Adjusted box office                object
# Actual box office                  object
# Adjusted budget                    object
# Actual budget                     float64
# Director                           object
# Rotten Tomatoes critic score       object
# Rotten Tomatoes audience score     object
# Golden Globe nominations            int64
# Golden Globe wins                   int64
# Academy Award nominations           int64
# Academy Award wins                  int64
# Number of Bond drinks             float64
# Bond girls                          int64
# Bond car make                      object
# Runtime minutes                     int64
# ...

# %%
bond.hist(column="Actual budget", figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0B56DB68>]],
#       dtype=object)

# %%
def big_budget(row):
    budget=row[10]
    if big_budget(row)>100:
        return "big budget"
    elif big_budget(row)<100:
        return "ehhh medium budget"
    else:
        return "small budget"

# %%
big_budget(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-684-1659c5d052d4> in <module>
# ----> 1 big_budget(100)
#
# <ipython-input-683-4c829cc39e34> in big_budget(row)
#       1 def big_budget(row):
# ----> 2     budget=row[10]
#       3     if big_budget(row)>100:
#       4         return "big budget"
#       5     elif big_budget(row)<100:
#
# TypeError: 'int' object is not subscriptable

# %%
bond["Rating"].astype('category')
# Out:
# Film
# A View to a Kill                      PG
# Casino Royale                      PG-13
# Diamonds Are Forever                  PG
# Die Another Day                    PG-13
# Dr. No                                PG
# For Your Eyes Only                    PG
# From Russia With Love                 PG
# GoldenEye                          PG-13
# Goldfinger                            PG
# Licence to Kill                        R
# Live and Let Die                      PG
# Moonraker                             PG
# Octopussy                             PG
# On Her Majesty's Secret Service       PG
# Quantum of Solace                  PG-13
# Skyfall                            PG-13
# The Living Daylights                  PG
# The Man with the Golden Gun           PG
# The Spy Who Loved Me                  PG
# The World is Not Enough            PG-13
# Thunderball                           PG
# Tomorrow Never Dies                PG-13
# You Only Live Twice                   PG
# ...

# %%
bond["Academy Award wins"]
# Out:
# Film
# A View to a Kill                   0
# Casino Royale                      0
# Diamonds Are Forever               0
# Die Another Day                    0
# Dr. No                             0
# For Your Eyes Only                 0
# From Russia With Love              0
# GoldenEye                          0
# Goldfinger                         1
# Licence to Kill                    0
# Live and Let Die                   0
# Moonraker                          0
# Octopussy                          0
# On Her Majesty's Secret Service    0
# Quantum of Solace                  0
# Skyfall                            2
# The Living Daylights               0
# The Man with the Golden Gun        0
# The Spy Who Loved Me               0
# The World is Not Enough            0
# Thunderball                        1
# Tomorrow Never Dies                0
# You Only Live Twice                0
# Name: Academy Award wins, dtype: int64

# %%
def good_movie(row):
    year=row[0]
    actor=row[2]
    
    if year>2000:
        return "new movie"
    elif year <1990:
        return "middle age movie"
    else:
        return "old movie"

# %%
bond['Bond girls']
# Out:
# Film
# A View to a Kill                   4
# Casino Royale                      2
# Diamonds Are Forever               5
# Die Another Day                    3
# Dr. No                             3
# For Your Eyes Only                 3
# From Russia With Love              3
# GoldenEye                          3
# Goldfinger                         5
# Licence to Kill                    2
# Live and Let Die                   3
# Moonraker                          4
# Octopussy                          3
# On Her Majesty's Secret Service    3
# Quantum of Solace                  2
# Skyfall                            2
# The Living Daylights               2
# The Man with the Golden Gun        4
# The Spy Who Loved Me               3
# The World is Not Enough            3
# Thunderball                        5
# Tomorrow Never Dies                3
# You Only Live Twice                4
# Name: Bond girls, dtype: int64

# %%
def alot_of_girls(row):
    girls=row[19]
    
    if girls==3:
        return "alot of girl"
    elif girls!=3:
        return "not that many girls"
    else:
        return "not enough girls"

# %%
"Hello World".upper()
# Out:
# 'HELLO WORLD'

# %%
"Brooke the cook".title()
# Out:
# 'Brooke The Cook'

# %%
"Brooke the cook".strip("B")
# Out:
# 'rooke the cook'

# %%
("$10000").strip("$")
# Out:
# '10000'

# %%
bond["Bond actor"].str.title()
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia With Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# The Living Daylights               Timothy Dalton
# The Man with the Golden Gun           Roger Moore
# The Spy Who Loved Me                  Roger Moore
# ...

# %%
bond['Director'].str.len()
# Out:
# Film
# A View to a Kill                    9
# Casino Royale                      15
# Diamonds Are Forever               12
# Die Another Day                    12
# Dr. No                             13
# For Your Eyes Only                  9
# From Russia With Love              13
# GoldenEye                          15
# Goldfinger                         12
# Licence to Kill                     9
# Live and Let Die                   12
# Moonraker                          13
# Octopussy                           9
# On Her Majesty's Secret Service    13
# Quantum of Solace                  12
# Skyfall                            10
# The Living Daylights                9
# The Man with the Golden Gun        12
# The Spy Who Loved Me               13
# The World is Not Enough            13
# Thunderball                        13
# Tomorrow Never Dies                18
# You Only Live Twice                13
# Name: Director, dtype: int64

# %%
"Brooke the cook".replace("o","0")
# Out:
# 'Br00ke the c00k'

# %%
bond['Bond actor']=bond['Bond actor'].str.replace("oger","ogeer")

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0    Rogeer Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0    Rogeer Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0    Rogeer Moore
# Moonraker                        1979          2.0    Rogeer Moore
# Octopussy                        1983          2.0    Rogeer Moore
# ...

# %%
# Out:
#   File "<ipython-input-722-1b4ecc301cb0>", line 1
#     for col in columns.str
#                           ^
# SyntaxError: invalid syntax

# %%
bond['Adjusted budget']=bond["Adjusted budget"].str.replace("millions","")

# %%
bond
# Out:
#                                  Year  Years lapse      Bond actor  \
# Film
# A View to a Kill                 1985          2.0    Rogeer Moore
# Casino Royale                    2006          4.0    Daniel Craig
# Diamonds Are Forever             1971          2.0    Sean Connery
# Die Another Day                  2002          3.0  Pierce Brosnan
# Dr. No                           1962          NaN    Sean Connery
# For Your Eyes Only               1981          2.0    Rogeer Moore
# From Russia With Love            1963          1.0    Sean Connery
# GoldenEye                        1995          6.0  Pierce Brosnan
# Goldfinger                       1964          1.0    Sean Connery
# Licence to Kill                  1989          2.0  Timothy Dalton
# Live and Let Die                 1973          2.0    Rogeer Moore
# Moonraker                        1979          2.0    Rogeer Moore
# Octopussy                        1983          2.0    Rogeer Moore
# ...

# %%
bond.hist(column="Actual budget", figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0AEE2580>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoint=np.array('Year lapse')

# %%
plt.plot(ypoint, linestyle="dotted", color='hotpink')

# %%
y_point=np.array("Year")
y_point
# Out:
# array('Year', dtype='<U4')

# %%
plt.plot(y_point, linestyle="dotted")

# %%
y_points=np.array("Adjusted budget")

# %%
plt.plot(y_point,scalex=False, linestyle='dotted', color='hotpink')

# %%
bond['Bond actor'].str.split(" ", expand=True)
# Out:
#                                        0        1
# Film
# A View to a Kill                  Rogeer    Moore
# Casino Royale                     Daniel    Craig
# Diamonds Are Forever                Sean  Connery
# Die Another Day                   Pierce  Brosnan
# Dr. No                              Sean  Connery
# For Your Eyes Only                Rogeer    Moore
# From Russia With Love               Sean  Connery
# GoldenEye                         Pierce  Brosnan
# Goldfinger                          Sean  Connery
# Licence to Kill                  Timothy   Dalton
# Live and Let Die                  Rogeer    Moore
# Moonraker                         Rogeer    Moore
# Octopussy                         Rogeer    Moore
# On Her Majesty's Secret Service   George  Lazenby
# Quantum of Solace                 Daniel    Craig
# Skyfall                           Daniel    Craig
# The Living Daylights             Timothy   Dalton
# The Man with the Golden Gun       Rogeer    Moore
# ...

# %%
bond.set_index(["Director","Actual budget"],inplace=True)

# %%
bond
# Out:
#                                   Years lapse  Bond actor appearance  \
# Director           Actual budget
# John Glen          30.0                   2.0                      7
# Martin Campbell    150.0                  4.0                      1
# Guy Hamilton       7.2                    2.0                      6
# Lee Tamahori       142.0                  3.0                      4
# Terence Young      1.1                    NaN                      1
# John Glen          28.0                   2.0                      5
# Terence Young      2.0                    1.0                      2
# Martin Campbell    60.0                   6.0                      1
# Guy Hamilton       3.0                    1.0                      3
# John Glen          36.0                   2.0                      2
# Guy Hamilton       7.0                    2.0                      1
# Lewis Gilbert      34.0                   2.0                      4
# ...

# %%
bond.sort_index(axis=1,ascending=False,inplace=True)

# %%
bond
# Out:
#                                   Years lapse  Villians Dispatched  \
# Director           Actual budget
# John Glen          30.0                   2.0                    5
# Martin Campbell    150.0                  4.0                   11
# Guy Hamilton       7.2                    2.0                    7
# Lee Tamahori       142.0                  3.0                   31
# Terence Young      1.1                    NaN                    4
# John Glen          28.0                   2.0                   18
# Terence Young      2.0                    1.0                   11
# Martin Campbell    60.0                   6.0                   47
# Guy Hamilton       3.0                    1.0                    9
# John Glen          36.0                   2.0                   10
# Guy Hamilton       7.0                    2.0                    8
# Lewis Gilbert      34.0                   2.0                   12
# ...

# %%
bond.index
# Out:
# MultiIndex([(         'John Glen',  30.0),
#             (   'Martin Campbell', 150.0),
#             (      'Guy Hamilton',   7.2),
#             (      'Lee Tamahori', 142.0),
#             (     'Terence Young',   1.1),
#             (         'John Glen',  28.0),
#             (     'Terence Young',   2.0),
#             (   'Martin Campbell',  60.0),
#             (      'Guy Hamilton',   3.0),
#             (         'John Glen',  36.0),
#             (      'Guy Hamilton',   7.0),
#             (     'Lewis Gilbert',  34.0),
#             (         'John Glen',  27.5),
#             (     'Peter R. Hunt',   7.0),
#             (      'Marc Forster', 200.0),
#             (        'Sam Mendes', 200.0),
#             (         'John Glen',  40.0),
#             (      'Guy Hamilton',   7.0),
#             (     'Lewis Gilbert',  14.0),
#             (     'Michael Apted', 135.0),
#             (     'Terence Young',   6.8),
#             ('Roger Spottiswoode', 110.0),
# ...
