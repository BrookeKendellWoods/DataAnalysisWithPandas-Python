# %%
import pandas as pd
import os 
import numpy as np

# %%
os.getcwd()
# Out:
# 'C:\\Users\\18174'

# %%
os.chdir("C:\\Users\\18174\\downloads")

# %%
worldstats=pd.read_csv("worldstats.csv",index_col=['country','year'])

# %%
worldstats.head(3)
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12

# %% [markdown]
# ##the stack method

# %%
worldstats.stack() #now have twice as many rows but half as many columns ( shifting or pivoting how df looks-> not changing contents
#only looking at it from a different angle ) #converted pandas df to a pandas series
# Out:
# country     year
# Arab World  2015  Population    3.920223e+08
#                   GDP           2.530102e+12
#             2014  Population    3.842226e+08
#                   GDP           2.873600e+12
#             2013  Population    3.765043e+08
#                                     ...
# Zimbabwe    1962  GDP           1.117602e+09
#             1961  Population    3.876638e+06
#                   GDP           1.096647e+09
#             1960  Population    3.752390e+06
#                   GDP           1.052990e+09
# Length: 22422, dtype: float64

# %%
worldstats.stack().to_frame()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
# ...                                  ...
# Zimbabwe   1962 GDP         1.117602e+09
#            1961 Population  3.876638e+06
#                 GDP         1.096647e+09
#            1960 Population  3.752390e+06
#                 GDP         1.052990e+09
#
# [22422 rows x 1 columns]

# %%
worldstats.unstack().unstack()
# Out:
#             year  country
# Population  1960  Afghanistan           8.994793e+06
#                   Albania                        NaN
#                   Algeria               1.112489e+07
#                   Andorra                        NaN
#                   Angola                         NaN
#                                             ...
# GDP         2015  West Bank and Gaza    1.267740e+10
#                   World                 7.343364e+13
#                   Yemen, Rep.                    NaN
#                   Zambia                2.120156e+10
#                   Zimbabwe              1.389294e+10
# Length: 28224, dtype: float64

# %%
worldstats.unstack(0)
# Out:
#          Population                                              \
# country Afghanistan    Albania     Algeria  Andorra      Angola
# year
# 1960      8994793.0        NaN  11124892.0      NaN         NaN
# 1961      9164945.0        NaN  11404859.0      NaN         NaN
# 1962      9343772.0        NaN  11690152.0      NaN         NaN
# 1963      9531555.0        NaN  11985130.0      NaN         NaN
# 1964      9728645.0        NaN  12295973.0      NaN         NaN
# 1965      9935358.0        NaN  12626953.0      NaN         NaN
# 1966     10148841.0        NaN  12980269.0      NaN         NaN
# 1967     10368600.0        NaN  13354197.0      NaN         NaN
# 1968     10599790.0        NaN  13744383.0      NaN         NaN
# 1969     10849510.0        NaN  14144437.0      NaN         NaN
# 1970     11121097.0        NaN  14550033.0  24279.0         NaN
# 1971     11412821.0        NaN  14960111.0  25560.0         NaN
# 1972     11716896.0        NaN  15377095.0  26892.0         NaN
# ...

# %%
worldstats.unstack('year')
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
worldstats.unstack(0)
# Out:
#          Population                                              \
# country Afghanistan    Albania     Algeria  Andorra      Angola
# year
# 1960      8994793.0        NaN  11124892.0      NaN         NaN
# 1961      9164945.0        NaN  11404859.0      NaN         NaN
# 1962      9343772.0        NaN  11690152.0      NaN         NaN
# 1963      9531555.0        NaN  11985130.0      NaN         NaN
# 1964      9728645.0        NaN  12295973.0      NaN         NaN
# 1965      9935358.0        NaN  12626953.0      NaN         NaN
# 1966     10148841.0        NaN  12980269.0      NaN         NaN
# 1967     10368600.0        NaN  13354197.0      NaN         NaN
# 1968     10599790.0        NaN  13744383.0      NaN         NaN
# 1969     10849510.0        NaN  14144437.0      NaN         NaN
# 1970     11121097.0        NaN  14550033.0  24279.0         NaN
# 1971     11412821.0        NaN  14960111.0  25560.0         NaN
# 1972     11716896.0        NaN  15377095.0  26892.0         NaN
# ...

# %%
worldstats.unstack('year',fill_value=0)
# Out:
#                       Population                                            \
# year                        1960          1961          1962          1963
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania             0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra             0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Angola              0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# ...                          ...           ...           ...           ...
# West Bank and Gaza  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.         0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# ...

# %%
worldstats.pivot_table(values='Population',index='country',columns='year',aggfunc="sum")
# Out:
# year                        1960          1961          1962          1963  \
# country
# Afghanistan         8.994793e+06  9.164945e+06  9.343772e+06  9.531555e+06
# Albania                      NaN           NaN           NaN           NaN
# Algeria             1.112489e+07  1.140486e+07  1.169015e+07  1.198513e+07
# Andorra                      NaN           NaN           NaN           NaN
# Angola                       NaN           NaN           NaN           NaN
# ...                          ...           ...           ...           ...
# West Bank and Gaza           NaN           NaN           NaN           NaN
# World               3.035056e+09  3.076121e+09  3.129064e+09  3.193947e+09
# Yemen, Rep.                  NaN           NaN           NaN           NaN
# Zambia              3.049586e+06  3.142848e+06  3.240664e+06  3.342894e+06
# Zimbabwe            3.752390e+06  3.876638e+06  4.006262e+06  4.140804e+06
#
# ...
